# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - 1.17
# - 1.16.5
# - 1.16.4
# - 1.16.3
# - 1.15.2
# - 1.14.4
# - 1.13.2
# - 1.12.2
# - 1.11.2
# - 1.10.2
# - 1.9.4
# - 1.8.8



version = '1.20.1' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit) 1.20.1 29/09/24 ultima version disponible
# - catserver (Versión de Minecraft que combina Forge y Bukkit) 1.18.2 29/09/24 ultima version disponible
# - purpur (Versión de Minecraft que combina paper y Bukkit)

server_type = 'mohist'

#Importa librerias necesarias para el funcionamiento del script 

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor 

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

if server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

if server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

if server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version

if server_type == 'fabric':
    serverURL = 'https://serverjars.com/api/fetchJar/modded/fabric/'

if server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version
    
if server_type == 'catserver':
    serverURL = "https://serverjars.com/api/fetchJar/modded/catserver/" + version

if server_type == 'purpur':
    serverURL = "https://serverjars.com/api/fetchJar/servers/purpur/" + version



jar_name = {'paper': 'server.jar', 'fabric': 'fabric-installer.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar", 
            'catserver': "catserver.jar", 'purpur': "purpur.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-installer.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# Completado!

# %%
#Tienes que poner el spawn proteccion en 0 para que puedas jugar de manera normal(esto dentro de Server.properties)
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading

import subprocess


#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)

# Instalar OpenJDK

version = colabconfig["server_version"]

# Ejecuta un comando en la terminal

def ejecutar_comando(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 17 installed")
    else:
        print("Failed to install OpenJDK 17")

# Purga versiones anteriores de OpenJDK
ejecutar_comando('sudo apt-get purge openjdk* -y')

# Instala OpenJDK 17
ejecutar_comando('sudo apt-get install openjdk-17-jre-headless -y')

# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

#Lista de posibles archivos .jar

jar_list = {'paper': 'server.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar", 'catserver': "catserver.jar", 'purpur': "purpur.jar"}

jar_name = jar_list[colabconfig["server_type"]]

# Argumentos de java.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok  #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2d8zRC8RGWWwyycpCjBHrCkSV9e_6B5UpefD6udmBi5WxGuAC" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))

elif tunnel_service == "playit":

    ! curl -SsL https://playit-cloud.github.io/ppa/key.gpg | sudo apt-key add -
    ! sudo curl -SsL -o /etc/apt/sources.list.d/playit-cloud.list https://playit-cloud.github.io/ppa/playit-cloud.list
    ! sudo apt update &>/dev/null && sudo apt install playit &>/dev/null && echo "Playit.gg installed" || echo "Failed to install playit"
    print('Starting server...')
    ! playit & java $memory_allocation $server_flags -jar $jar_name nogui

print('Iniciando servidor...')

def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

if colabconfig["server_type"] == "forge":

    version = colabconfig["server_version"]

    if colabconfig["server_version"] < "1.17":

        oldpathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/forge-{version}-*.jar")

        if oldpathtoforge: # Checa si la lista no esta vacia

            path = oldpathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java $memory_allocation -jar "{path}" nogui

        else:

            print("No se encontro la version de Forge universal.")

    else:

        pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{version}-/unix_.txt")

        if pathtoforge: # Checa si la lista no esta vacia

            path = pathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java @user_jvm_args.txt "@{path}" "$@"

        else:

            print("No unix_args.txt found.")
else:

    # !java $memory_allocation $server_flags -jar $jar_name nogui



# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)  # Espera 1 minuto
# Out:
# el apt cache fue actualizado correctamente
# banned-ips.json      forge.jar	    ops.json	       usercache.json
# banned-players.json  forge.jar.log  permissions.yml    whitelist.json
# bukkit.yml	     help.yml	    plugins	       world
# colabconfig.json     libraries	    run.bat	       xaerominimap-common.txt
# commands.yml	     logs	    run.sh	       xaeroworldmap-common.txt
# config		     mods	    server.properties
# defaultconfigs	     mohist-config  spigot.yml
# eula.txt	     mohist.jar     user_jvm_args.txt
# OpenJDK 17 installed
# OpenJDK 17 installed
# Usando ngrok
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es 0.tcp.ngrok.io:11554
# Iniciando servidor...
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
#
#  ███╗   ███╗  ██████╗  ██╗  ██╗ ██╗ ███████╗ ████████╗
#  ████╗ ████║ ██╔═══██╗ ██║  ██║ ██║ ██╔════╝ ╚══██╔══╝
#  ██╔████╔██║ ██║   ██║ ███████║ ██║ ███████╗    ██║
#  ██║╚██╔╝██║ ██║   ██║ ██╔══██║ ██║ ╚════██║    ██║
#  ██║ ╚═╝ ██║ ╚██████╔╝ ██║  ██║ ██║ ███████║    ██║
#  ╚═╝     ╚═╝  ╚═════╝  ╚═╝  ╚═╝ ╚═╝ ╚══════╝    ╚═╝
#
#
# Thanks for using Mohist - 1.20.1-580, Java(21.0.2) 65.0 PID: 43550
#
# Update in check...
# If you don't want to enable update check, set check_update in mohist-config/mohist.yml to false
# The latest Mohist version is 1.20.1-623 but you have 1.20.1-580. The latest version has been built on 2024-03-15 09:26:35. You should update to fix recent bugs!
# Checking libraries, please wait...
# All libraries are nice :)!
# Searching incompatible mods...
# [18:12:11 INFO]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 47.2.20, --fml.mcVersion, 1.20.1, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20230612.114412, nogui]
# [18:12:11 INFO]: ModLauncher 10.0.9+10.0.9+main.dcd20f30 starting: java version 21.0.2 by Microsoft; OS Linux arch amd64 version 6.2.0-1019-azure
# [18:12:11 INFO]: ImmediateWindowProvider not loading because launch target is forgeserver
# [18:12:11 INFO]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%23111!/ Service=ModLauncher Env=SERVER
# [18:12:11 WARN]: Attempted to select two dependency jars from JarJar which have the same identification: Mod File:  and Mod File: . Using Mod File:
# [18:12:11 INFO]: Found 4 dependencies adding them to mods collection
# [18:12:14 INFO]: Compatibility level set to JAVA_17
# [18:12:14 ERROR]: Mixin config okzoomer.mixins.json does not specify "minVersion" property
# [18:12:14 INFO]: Launching target 'forgeserver' with arguments [nogui]
# [18:12:14 WARN]: Reference map 'trashslot.refmap.json' for trashslot.mixins.json could not be read. If this is a development environment you can ignore this message
# [18:12:14 INFO]: Loaded configuration file for Embeddium: 85 options available, 0 override(s) found
# [18:12:14 WARN]: Reference map 'cristellib-forge-refmap.json' for cristellib.mixins.json could not be read. If this is a development environment you can ignore this message
# [18:12:15 WARN]: Error loading class: noobanidus/mods/lootr/config/ConfigManager (java.lang.ClassNotFoundException: noobanidus.mods.lootr.config.ConfigManager)
# [18:12:16 INFO]: Initializing MixinExtras via com.llamalad7.mixinextras.service.MixinExtrasServiceImpl(version=0.3.2).
# [Mouse Tweaks] Disabled because not running on the client.
# [18:12:23 INFO]: Registering C2S receiver with id architectury:sync_ids
# [18:12:23 INFO]: Registering C2S receiver with id artifacts:networking_channel/42a7ad70b1cc371599a0eff744096b8a
# [18:12:23 INFO]: Registering C2S receiver with id artifacts:networking_channel/74a5e841822a3a87854ae896a33430d6
# [18:12:23 INFO]: Registering C2S receiver with id artifacts:networking_channel/eb3d1e2748533430848cadf0f37c7e9c
# [18:12:23 INFO]: Registering C2S receiver with id artifacts:networking_channel/91c8520f19f93b3e8b6a727568e194ab
# [18:12:23 INFO]: Registering C2S receiver with id artifacts:networking_channel/8c2784d778293fd482ed84b8aa5fedb9
# [18:12:23 INFO]: Forge mod loading, version 47.2.20, for MC 1.20.1 with MCP 20230612.114412
# [18:12:23 INFO]: MinecraftForge v47.2.20 Initialized
# [18:12:23 INFO]: NeoForge v47.2.20 Initialized
# [18:12:23 INFO]: Mohist mod loading.....
# [18:12:23 INFO]: EventDispatcherRegistry initialized
# [18:12:23 INFO]: ExpandAbility here, who dis?
# [18:12:23 ERROR]: Attempted to load class net/minecraft/client/Minecraft for invalid dist DEDICATED_SERVER
# [18:12:23 ERROR]: Failed to update fingerprint
# java.lang.NoClassDefFoundError: net/minecraft/client/Minecraft
# 	at me.jellysquid.mods.sodium.client.data.fingerprint.FingerprintMeasure.create(FingerprintMeasure.java:19) ~[embeddium-0.3.4+mc1.20.1.jar%23239!/:?]
# 	at me.jellysquid.mods.sodium.client.SodiumClientMod.updateFingerprint(SodiumClientMod.java:104) ~[embeddium-0.3.4+mc1.20.1.jar%23239!/:?]
# 	at me.jellysquid.mods.sodium.client.SodiumClientMod.<init>(SodiumClientMod.java:45) ~[embeddium-0.3.4+mc1.20.1.jar%23239!/:?]
# 	at jdk.internal.reflect.DirectConstructorHandleAccessor.newInstance(DirectConstructorHandleAccessor.java:62) ~[?:?]
# 	at java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:502) ~[?:?]
# 	at java.lang.reflect.Constructor.newInstance(Constructor.java:486) ~[?:?]
# 	at net.minecraftforge.fml.javafmlmod.FMLModContainer.constructMod(FMLModContainer.java:76) ~[javafmllanguage-1.20.1-47.2.20.jar%23262!/:?]
# 	at net.minecraftforge.fml.ModContainer.lambda$buildTransitionHandler$10(ModContainer.java:123) ~[fmlcore-1.20.1-47.2.20.jar%23261!/:?]
# 	at java.util.concurrent.CompletableFuture$AsyncRun.run(CompletableFuture.java:1804) [?:?]
# 	at java.util.concurrent.CompletableFuture$AsyncRun.exec(CompletableFuture.java:1796) [?:?]
# 	at java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:387) [?:?]
# 	at java.util.concurrent.ForkJoinPool$WorkQueue.topLevelExec(ForkJoinPool.java:1312) [?:?]
# 	at java.util.concurrent.ForkJoinPool.scan(ForkJoinPool.java:1843) [?:?]
# 	at java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1808) [?:?]
# 	at java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:188) [?:?]
# Caused by: java.lang.ClassNotFoundException: net.minecraft.client.Minecraft
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:157) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?]
# 	... 15 more
# [18:12:23 INFO]: Discovered 160 modules to load.
# [18:12:23 INFO]: Constructing module Abacus...
# [18:12:23 INFO]: Constructing module Adjustable Chat...
# [18:12:23 INFO]: Constructing module Ambient Discs...
# [18:12:23 INFO]: Constructing module Ancient Tomes...
# [18:12:23 INFO]: Constructing module Ancient Wood...
# [18:12:23 INFO]: Constructing module Armed Armor Stands...
# [18:12:23 INFO]: Constructing module Auto Walk Keybind...
# [18:12:23 INFO]: Constructing module Automatic Recipe Unlock...
# [18:12:23 INFO]: Constructing module Automatic Tool Restock...
# [18:12:23 INFO]: Constructing module Azalea Wood...
# [18:12:23 INFO]: Constructing module Back Button Keybind...
# [18:12:23 INFO]: Constructing module Backpack...
# [18:12:23 INFO]: Constructing module Beacon Redirection...
# [18:12:23 INFO]: Constructing module Better Elytra Rocket...
# [18:12:23 INFO]: Constructing module Big Stone Clusters...
# [18:12:23 INFO]: Constructing module Blossom Trees...
# [18:12:23 INFO]: Constructing module Bottled Cloud...
# [18:12:23 INFO]: Constructing module Buckets Show Inhabitants...
# [18:12:23 INFO]: Constructing module Camera...
# [18:12:23 INFO]: Constructing module Campfires Boost Elytra...
# [18:12:23 INFO]: Constructing module Celebratory Lamps...
# [18:12:23 INFO]: Constructing module Chains Connect Blocks...
# [18:12:23 INFO]: Constructing module Chest Searching...
# [18:12:23 INFO]: Constructing module Chorus Vegetation...
# [18:12:23 INFO]: Constructing module Chute...
# [18:12:23 INFO]: Constructing module Climate Control Remover...
# [18:12:23 INFO]: Constructing module Color Runes...
# [18:12:23 INFO]: Constructing module Compasses Work Everywhere...
# [18:12:23 INFO]: Constructing module Compressed Blocks...
# [18:12:23 INFO]: Constructing module Coral On Cactus...
# [18:12:23 INFO]: Constructing module Corundum...
# [18:12:23 INFO]: Constructing module Crabs...
# [18:12:23 INFO]: Constructing module Crafter...
# [18:12:23 INFO]: Constructing module Crate...
# [18:12:23 INFO]: Constructing module Diamond Repair...
# [18:12:23 INFO]: Constructing module Dispensers Place Blocks...
# [18:12:23 INFO]: Constructing module Double Door Opening...
# [18:12:23 INFO]: Constructing module Dragon Scales...
# [18:12:23 INFO]: Constructing module Duskbound Blocks...
# [18:12:23 INFO]: Constructing module Dyeable Item Frames...
# [18:12:23 INFO]: Constructing module Easy Transfering...
# [18:12:23 INFO]: Constructing module Elytra Indicator...
# [18:12:23 INFO]: Constructing module Emotes...
# [18:12:23 INFO]: Constructing module Enchantment Predicates...
# [18:12:23 INFO]: Constructing module Enchantments Begone...
# [18:12:23 INFO]: Constructing module Ender Watcher...
# [18:12:23 INFO]: Constructing module Endermosh Music Disc...
# [18:12:23 INFO]: Constructing module Enhanced Ladders...
# [18:12:23 INFO]: Constructing module Expanded Item Interactions...
# [18:12:23 INFO]: Constructing module Fairy Rings...
# [18:12:23 INFO]: Constructing module Feeding Trough...
# [18:12:23 INFO]: Constructing module Forgotten...
# [18:12:23 INFO]: Constructing module Foxhound...
# [18:12:24 INFO]: Constructing module Framed Glass...
# [18:12:24 INFO]: Constructing module Game Nerfs...
# [18:12:24 INFO]: Constructing module Glass Item Frame...
# [18:12:24 INFO]: Constructing module Glass Shard...
# [18:12:24 INFO]: Constructing module Glimmering Weald...
# [18:12:24 INFO]: Constructing module Gold Bars...
# [18:12:24 INFO]: Constructing module Gold Tools Have Fortune...
# [18:12:24 INFO]: Constructing module Grab Chickens...
# [18:12:24 INFO]: Constructing module Grate...
# [18:12:24 INFO]: Constructing module Gravisand...
# [18:12:24 INFO]: Constructing module Greener Grass...
# [18:12:24 INFO]: Constructing module Hedges...
# [18:12:24 INFO]: Constructing module Hoe Harvesting...
# [18:12:24 INFO]: Constructing module Hollow Logs...
# [18:12:24 INFO]: Constructing module Horses Swim...
# [18:12:24 INFO]: Constructing module Hotbar Changer...
# [18:12:24 INFO]: Constructing module Improved Sponges...
# [18:12:24 INFO]: Constructing module Improved Tooltips...
# [18:12:24 INFO]: Constructing module Industrial Palette...
# [18:12:24 INFO]: Constructing module Inventory Sorting...
# [18:12:24 INFO]: Constructing module Iron Rod...
# [18:12:24 INFO]: Constructing module Item Sharing...
# [18:12:24 INFO]: Constructing module Japanese Palette...
# [18:12:24 INFO]: Constructing module Leaf Carpet...
# [18:12:24 INFO]: Constructing module Lock Rotation...
# [18:12:24 INFO]: Constructing module Long Range Pick Block...
# [18:12:24 INFO]: Constructing module Magnets...
# [18:12:24 INFO]: Constructing module Map Washing...
# [18:12:24 INFO]: Constructing module Matrix Enchanting...
# [18:12:24 INFO]: Constructing module Metal Buttons...
# [18:12:24 INFO]: Constructing module Microcrafting Helper...
# [18:12:24 INFO]: Constructing module Midori...
# [18:12:24 INFO]: Constructing module Monster Box...
# [18:12:24 INFO]: Constructing module More Banner Layers...
# [18:12:24 INFO]: Constructing module More Brick Types...
# [18:12:24 INFO]: Constructing module More Mud Blocks...
# [18:12:24 INFO]: Constructing module More Note Block Sounds...
# [18:12:24 INFO]: Constructing module More Potted Plants...
# [18:12:24 INFO]: Constructing module Narrator Readout...
# [18:12:24 INFO]: Constructing module Nether Brick Fence Gate...
# [18:12:24 INFO]: Constructing module Nether Obsidian Spikes...
# [18:12:24 INFO]: Constructing module New Stone Types...
# [18:12:24 INFO]: Constructing module No Durability On Cosmetics...
# [18:12:24 INFO]: Constructing module No More Lava Pockets...
# [18:12:24 INFO]: Constructing module Obsidian Plate...
# [18:12:24 INFO]: Constructing module Overlay Shader...
# [18:12:24 INFO]: Constructing module Parrot Eggs...
# [18:12:24 INFO]: Constructing module Pat The Dogs...
# [18:12:24 INFO]: Constructing module Pathfinder Maps...
# [18:12:24 INFO]: Constructing module Permafrost...
# [18:12:24 INFO]: Constructing module Pickarang...
# [18:12:24 INFO]: Constructing module Pig Litters...
# [18:12:24 INFO]: Constructing module Pipes...
# [18:12:24 INFO]: Constructing module Pistons Move Tile Entities...
# [18:12:24 INFO]: Constructing module Poison Potato Usage...
# [18:12:24 INFO]: Constructing module Quick Armor Swapping...
# [18:12:24 INFO]: Constructing module Rainbow Lamps...
# [18:12:24 INFO]: Constructing module Raw Metal Bricks...
# [18:12:24 INFO]: Constructing module Reacharound Placing...
# [18:12:24 INFO]: Constructing module Redstone Randomizer...
# [18:12:24 INFO]: Constructing module Renewable Spore Blossoms...
# [18:12:24 INFO]: Constructing module Replace Scaffolding...
# [18:12:24 INFO]: Constructing module Rope...
# [18:12:24 INFO]: Constructing module Safer Creatures...
# [18:12:24 INFO]: Constructing module Seed Pouch...
# [18:12:24 INFO]: Constructing module Shear Vines...
# [18:12:24 INFO]: Constructing module Shiba...
# [18:12:24 INFO]: Constructing module Shingles...
# [18:12:24 INFO]: Constructing module Shulker Packing...
# [18:12:24 INFO]: Constructing module Simple Harvest...
# [18:12:24 INFO]: Constructing module Skull Pikes...
# [18:12:24 INFO]: Constructing module Slabs To Blocks...
# [18:12:24 INFO]: Constructing module Slime In A Bucket...
# [18:12:24 INFO]: Constructing module Slimes To Magma Cubes...
# [18:12:24 INFO]: Constructing module Snow Golem Player Heads...
# [18:12:24 INFO]: Constructing module Soul Candles...
# [18:12:24 INFO]: Constructing module Soul Sandstone...
# [18:12:24 INFO]: Constructing module Spawner Replacer...
# [18:12:24 INFO]: Constructing module Spiral Spires...
# [18:12:24 INFO]: Constructing module Stonelings...
# [18:12:24 INFO]: Constructing module Stools...
# [18:12:24 INFO]: Constructing module Sturdy Stone...
# [18:12:24 INFO]: Constructing module Thatch...
# [18:12:24 INFO]: Constructing module Tiny Potato...
# [18:12:24 INFO]: Constructing module Torch Arrow...
# [18:12:24 INFO]: Constructing module Toretoise...
# [18:12:24 INFO]: Constructing module Totem Of Holding...
# [18:12:24 INFO]: Constructing module Trowel...
# [18:12:24 INFO]: Constructing module Usage Ticker...
# [18:12:24 INFO]: Constructing module Uses For Curses...
# [18:12:24 INFO]: Constructing module Utility Recipes...
# [18:12:24 INFO]: Constructing module Variant Animal Textures...
# [18:12:24 INFO]: Constructing module Variant Bookshelves...
# [18:12:24 INFO]: Constructing module Variant Chests...
# [18:12:24 INFO]: Constructing module Variant Furnaces...
# [18:12:24 INFO]: Constructing module Variant Ladders...
# [18:12:24 INFO]: Constructing module Variant Selector...
# [18:12:24 INFO]: Constructing module Vertical Planks...
# [18:12:24 INFO]: Constructing module Vertical Slabs...
# [18:12:24 INFO]: Constructing module Vexes Die With Their Masters...
# [18:12:24 INFO]: Constructing module Villager Rerolling Rework...
# [18:12:24 INFO]: Constructing module Villagers Follow Emeralds...
# [18:12:24 INFO]: Constructing module Wooden Posts...
# [18:12:24 INFO]: Constructing module Wool Shuts Up Minecarts...
# [18:12:24 INFO]: Constructing module Wraith...
# [18:12:24 INFO]: Constructing module Zombie Villagers On Normal...
# [18:12:24 INFO]: Constructing module More Stone Variants...
# [18:12:24 INFO]: Constructed 160 modules.
# [18:12:24 INFO]: Dispatching ZRegister to 3 listeners
# [18:12:24 INFO]: Dispatching ZRegister$Post to 1 listener
# [18:12:24 INFO]: Dispatching ZRegister to 96 listeners
# [18:12:27 INFO]: Dispatching ZRegister$Post to 6 listeners
# [18:12:29 INFO]: Dispatching ForgeZEntityAttributeCreation (as ZEntityAttributeCreation) to 7 listeners
# [18:12:29 INFO]: Dispatching ZConfigChanged to 2 listeners
# [18:12:29 INFO]: 'zeta' is enabling Zeta's piston structure resolver.
# [18:12:29 INFO]: Dispatching ZConfigChanged to 45 listeners
# [18:12:29 INFO]: Dispatching ZConfigChanged to 45 listeners
# [18:12:29 INFO]: Dispatching ForgeZCommonSetup (as ZCommonSetup) to 2 listeners
# [18:12:29 INFO]: Dispatching ForgeZCommonSetup (as ZCommonSetup) to 40 listeners
# [18:12:30 INFO]: Dispatching ZConfigChanged to 45 listeners
# [18:12:30 INFO]: Dispatching ZConfigChanged to 2 listeners
# [18:12:30 INFO]: Loading Xaero's Minimap - Stage 1/2 (Server)
# [18:12:30 INFO]: Loading Xaero's World Map - Stage 1/2 (Server)
# [18:12:30 INFO]: Loading Xaero's Minimap - Stage 2/2 (Server)
# [18:12:30 INFO]: Loading Xaero's World Map - Stage 2/2 (Server)
# [18:12:30 INFO]: Dispatching ForgeZLoadComplete (as ZLoadComplete) to 1 listener
# [18:12:30 INFO]: Dispatching ForgeZLoadComplete (as ZLoadComplete) to 6 listeners
# [18:12:30 INFO]: Start loading plugin at snownee.jade.addon.vanilla.VanillaPlugin
# [18:12:30 INFO]: Start loading plugin at snownee.jade.addon.universal.UniversalPlugin
# [18:12:30 INFO]: Start loading plugin at snownee.jade.addon.core.CorePlugin
# [18:12:30 INFO]: Start loading plugin at ovh.corail.tombstone.compatibility.IntegrationJade
# [18:12:35 INFO]: Environment: authHost='https://authserver.mojang.com', accountsHost='https://api.mojang.com', sessionHost='https://sessionserver.mojang.com', servicesHost='https://api.minecraftservices.com', name='PROD'
# [18:12:38 ERROR]: Cristel Lib Config Pack has no data
# [18:12:38 ERROR]: T&T Waystone Patch Pack condition is false, skipping
# [18:12:40 INFO]: Adding datapack listener capsid_recipes
# [18:12:40 INFO]: Dispatching ForgeZAddReloadListener (as ZAddReloadListener) to 2 listeners
# [18:12:40 INFO]: Dispatching ForgeZAddReloadListener (as ZAddReloadListener) to 2 listeners
# [18:12:40 WARN]: Tag entries for curios:tags/items/magic_book.json cleared by tombstone-1.20.1-8.6.3.jar
# [18:12:40 INFO]: Loaded 8 recipes
# [18:12:41 INFO]: [Automatic Recipe Unlock] Removed 1223 recipe advancements
# [18:12:41 INFO]: Loaded 553 advancements
# [18:12:41 INFO]: Loaded 13 curio slots
# [18:12:41 INFO]: Loaded 1 curio entities
# [18:12:41 INFO]: Modified advancement minecraft:husbandry/wax_on with 2 patches
# [18:12:41 INFO]: Modified advancement minecraft:adventure/kill_a_mob with 3 patches
# [18:12:41 INFO]: Modified advancement minecraft:husbandry/bred_all_animals with 3 patches
# [18:12:41 INFO]: Modified advancement minecraft:adventure/kill_all_mobs with 3 patches
# [18:12:41 INFO]: Modified advancement minecraft:husbandry/balanced_diet with 2 patches
# [18:12:41 INFO]: Modified advancement minecraft:nether/all_effects with 1 patches
# [18:12:41 INFO]: Modified advancement minecraft:husbandry/wax_off with 2 patches
# [18:12:41 INFO]: Modified advancement minecraft:adventure/adventuring_time with 1 patches
# [18:12:41 INFO]: Modified advancement minecraft:nether/all_potions with 1 patches
# [18:12:44 INFO]: Dispatching ZTagsUpdated to 1 listener
# [18:12:44 INFO]: Starting minecraft server version 1.20.1
# [18:12:44 INFO]: Loading properties
# [18:12:44 INFO]: Default game type: SURVIVAL
# [18:12:44 INFO]: Generating keypair
# [18:12:44 INFO]: Starting Minecraft server on *:25565
# [18:12:44 INFO]: Using epoll channel type
# [18:12:44 INFO]: This server is running Mohist version 1.20.1-580 (MC: 1.20.1) (Implementing API version 1.20.1-R0.1-SNAPSHOT, Forge version 47.2.20, NeoForge version 47.1.79)
# [18:12:46 INFO]: Debug logging is enabled
# [18:12:46 INFO]: Server Ping Player Sample Count: 20
# [18:12:46 INFO]: Using 4 threads for Netty based IO
# [18:12:46 INFO]: Hello Plugins!
# [18:12:46 INFO]: THe OkZoomer server config has been changed!
# [18:12:46 INFO]: Preparing level "world"
# [18:12:51 INFO]: Preparing start region for dimension minecraft:overworld
# [18:12:56 INFO]: Preparing spawn area: 0%
# [18:12:56 INFO]: Preparing spawn area: 0%
# [18:12:56 INFO]: Preparing spawn area: 0%
# [18:12:56 INFO]: Preparing spawn area: 0%
# [18:12:56 INFO]: Preparing spawn area: 0%
# [18:12:56 INFO]: Preparing spawn area: 0%
# [18:12:56 INFO]: Preparing spawn area: 0%
# [18:12:56 INFO]: Preparing spawn area: 0%
# [18:12:56 INFO]: Preparing spawn area: 0%
# [18:12:56 INFO]: Preparing spawn area: 0%
# [18:12:56 INFO]: Preparing spawn area: 0%
# [18:12:56 INFO]: Preparing spawn area: 24%
# [18:12:57 INFO]: Time elapsed: 5969 ms
# [18:12:57 INFO]: Preparing start region for dimension minecraft:the_nether
# [18:12:57 INFO]: Preparing spawn area: 0%
# [18:12:58 INFO]: Preparing spawn area: 0%
# [18:12:58 INFO]: Preparing spawn area: 0%
# [18:12:59 INFO]: Preparing spawn area: 1%
# [18:12:59 INFO]: Preparing spawn area: 4%
# [18:13:00 INFO]: Preparing spawn area: 5%
# [18:13:00 INFO]: Preparing spawn area: 37%
# [18:13:00 INFO]: Time elapsed: 3269 ms
# [18:13:00 INFO]: Preparing start region for dimension minecraft:the_end
# [18:13:01 INFO]: Preparing spawn area: 0%
# [18:13:01 INFO]: Preparing spawn area: 0%
# [18:13:01 INFO]: Preparing spawn area: 0%
# [18:13:02 INFO]: Preparing spawn area: 1%
# [18:13:02 INFO]: Preparing spawn area: 30%
# [18:13:03 INFO]: Time elapsed: 2440 ms
# [18:13:03 INFO]: [Mohist] Enabling Mohist v1.20.1
# [18:13:03 INFO]: Server permissions file permissions.yml is empty, ignoring it
# [18:13:03 INFO]: Done (17.478s)! For help, type "help"
# [18:13:03 INFO]: Successfully initialized permission handler forge:default_handler
# [18:13:03 INFO]: Forwarding forge permission[forge:default_handler] to bukkit[mohist:permission]
# [18:13:17 WARN]: UUID of added entity already exists: Bee['Bee'/671, l='ServerLevel[world]', x=-67.50, y=69.20, z=-67.60]
# >
